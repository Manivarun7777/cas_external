# %%
sentence = "the cat and the hat"

words = sentence.split()
word_count = {}

for word in words:
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print(word_count)
# Out:
# {'the': 2, 'cat': 1, 'and': 1, 'hat': 1}
